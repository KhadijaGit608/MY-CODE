# %%
temp1 = int(input("Enter first temperature."))
temp2 = int(input("Enter second temperature."))
conversion = temp1 * 9/5 + 32
print("The conversion of celsius to farenheit is:",conversion)
# Out:
# Enter first temperature.14
# Enter second temperature.15
# The conversion of celsius to farenheit is: 57.2

# %%
usd_amount = int(input("Enter the amount you have in usd: "))
conversion_rate = int(input("Enter the coversion rate: "))
local_currency_amount = usd_amount*conversion_rate
print("You have", usd_amount, "USD.")
print("The Conversion rate is ", conversion_rate)
print("You will get", local_currency_amount, "in local currency.")
# Out:
# Enter the amount you have in usd: 304
# Enter the coversion rate: 21
# You have 304 USD.
# The Conversion rate is  21
# You will get 6384 in local currency.

# %%
num1 = int(input("Enter first number."))
num2 = int(input("Enter second number."))
addition = num1 + num2
print("The sum of num1 and num2 is:",addition)
# Out:
# Enter first number.20
# Enter second number.30
# The sum of num1 and num2 is: 50

# %%
Length = 8
Width = 7

Area = Length * Width
print("The area of rectangle is:", Area)
# Out:
# The area of rectangle is: 56

# %%
minutes = 55
seconds = minutes * 60
print("Total seconds are:",seconds)
# Out:
# Total seconds are: 3300

# %% [markdown]
# # New section
